# %%
import sys, os

path2add = os.path.normpath(os.path.abspath(os.path.join(os.path.dirname('__file__'), os.path.pardir, 'src')))
if not path2add in sys.path:
    sys.path.append(path2add)

import pandas as pd
import plotly.express as px

# %%
    diet_titles = [
        'High-fiber meals', 
        'Cholesterol friendly foods', 
        'Mediterranean diet',
        'Healthy eating guide', 
        'Weight management'
    ]

    physical_activity_titles = [
        'Aerobic exercise',
        'Exercise routines', 
        'Strength training basics', 
        'Cardio workouts'
    ]

    sleep_health_titles = [
        'Restorative sleep tips', 
        'Sleep hygiene'
    ]

    resilience_wellbeing_titles = [
        'Stress reduction',
        'Meditation guide'
    ]

    clinical_titles = [
        'Diabetes management',
        'Hypertension basics',
        'Lowering blood pressure',
        'Cardiometabolic health',
        'HbA1c targets'
    ]

# %%
web_visits = pd.read_csv('../data/web_visits.csv')
web_visits
# Out:
#         member_id                                   url  \
# 0               1     https://health.wellco/chronic/859
# 1               1          https://portal.site/tech/328
# 2               1       https://health.wellco/heart/792
# 3               2        https://example.com/gaming/674
# 4               2      https://living.better/stress/325
# ...           ...                                   ...
# 259335      10000        https://example.com/travel/387
# 259336      10000  https://guide.wellness/nutrition/261
# 259337      10000            https://media.hub/tech/799
# 259338      10000          https://media.hub/movies/326
# 259339      10000          https://portal.site/cars/271
#
#                              title                               description  \
# 0              Diabetes management          Blood sugar and glycemic control
# 1                   Gadget roundup              Smartphones and laptops news
# 2              Hypertension basics      Blood pressure and lifestyle changes
# 3                     Game reviews                 Strategy tips and updates
# 4                 Stress reduction                  Mindfulness and wellness
# ...                            ...                                       ...
# 259335            Top destinations               City guides and itineraries
# 259336  Cholesterol friendly foods  Lowering LDL and improving lipid profile
# 259337              Gadget roundup              Smartphones and laptops news
# 259338                New releases                   Box office and trailers
# 259339           Electric vehicles               Charging networks and range
#
#                   timestamp
# 0       2025-07-02 22:38:22
# 1       2025-07-02 11:30:47
# 2       2025-07-14 00:38:39
# 3       2025-07-07 02:56:06
# 4       2025-07-02 15:53:38
# ...                     ...
# 259335  2025-07-05 00:05:16
# 259336  2025-07-13 01:15:16
# 259337  2025-07-11 01:22:25
# 259338  2025-07-01 13:55:49
# 259339  2025-07-06 02:34:55
#
# [259340 rows x 5 columns]

# %%
def categorize_web_titles(df: pd.DataFrame, title_column: str = 'title') -> pd.DataFrame:
    """
    Categorizes web visit titles into predefined health categories.
    
    Parameters:
    -----------
    df : pd.DataFrame
        DataFrame containing web visit data
    title_column : str
        Name of the column containing titles (default: 'title')
    
    Returns:
    --------
    pd.DataFrame
        Original DataFrame with added 'category' column
    """
    
    # Define category mappings
    categories = {
        'diet': [
            'High-fiber meals', 
            'Cholesterol friendly foods', 
            'Mediterranean diet',
            'Healthy eating guide', 
            'Weight management'
        ],
        'physical_activity': [
            'Aerobic exercise',
            'Exercise routines', 
            'Strength training basics', 
            'Cardio workouts'
        ],
        'sleep': [
            'Restorative sleep tips', 
            'Sleep hygiene'
        ],
        'resilience': [
            'Stress reduction',
            'Meditation guide'
        ],
        'clinical': [
            'Diabetes management',
            'Hypertension basics',
            'Lowering blood pressure',
            'Cardiometabolic health',
            'HbA1c targets'
        ]
    }
    
    # Create a mapping dictionary for faster lookup
    title_to_category = {}
    for category, titles in categories.items():
        for title in titles:
            title_to_category[title] = category
    
    # Map titles to categories
    df = df.copy()
    df['category'] = df[title_column].map(title_to_category).fillna('unrelated')
    
    return df

web_visits_processed = categorize_web_titles(web_visits)
web_visits[web_visits['title'] == 'Cardiometabolic health']
# Out:
#         member_id                                      url  \
# 11              2     https://care.portal/hypertension/926
# 17              3  https://guide.wellness/hypertension/479
# 55              3   https://living.better/hypertension/629
# 97              6   https://health.wellco/hypertension/350
# 98              6     https://care.portal/hypertension/261
# ...           ...                                      ...
# 259237       9996   https://health.wellco/hypertension/521
# 259238       9996     https://care.portal/hypertension/505
# 259248       9998   https://living.better/hypertension/516
# 259296      10000   https://health.wellco/hypertension/567
# 259311      10000  https://guide.wellness/hypertension/450
#
#                           title                                 description  \
# 11      Lowering blood pressure  Lifestyle changes and medication adherence
# 17      Lowering blood pressure  Lifestyle changes and medication adherence
# 55      Lowering blood pressure  Lifestyle changes and medication adherence
# 97      Lowering blood pressure  Lifestyle changes and medication adherence
# 98      Lowering blood pressure  Lifestyle changes and medication adherence
# ...                         ...                                         ...
# 259237  Lowering blood pressure  Lifestyle changes and medication adherence
# 259238  Lowering blood pressure  Lifestyle changes and medication adherence
# 259248  Lowering blood pressure  Lifestyle changes and medication adherence
# 259296  Lowering blood pressure  Lifestyle changes and medication adherence
# 259311  Lowering blood pressure  Lifestyle changes and medication adherence
#
#                   timestamp
# 11      2025-07-03 14:32:58
# 17      2025-07-13 17:32:01
# 55      2025-07-09 04:53:50
# 97      2025-07-05 16:26:47
# 98      2025-07-14 07:10:10
# ...                     ...
# 259237  2025-07-04 07:19:48
# 259238  2025-07-01 09:12:03
# 259248  2025-07-11 04:05:15
# 259296  2025-07-11 03:58:55
# 259311  2025-07-03 19:49:03
#
# [5640 rows x 5 columns]

# %%
web_visits_pattern = web_visits_processed.drop(columns=['url', 'title', 'description'])
web_visits_pattern
# Out:
#         member_id            timestamp    category
# 0               1  2025-07-02 22:38:22    clinical
# 1               1  2025-07-02 11:30:47   unrelated
# 2               1  2025-07-14 00:38:39    clinical
# 3               2  2025-07-07 02:56:06   unrelated
# 4               2  2025-07-02 15:53:38  resilience
# ...           ...                  ...         ...
# 259335      10000  2025-07-05 00:05:16   unrelated
# 259336      10000  2025-07-13 01:15:16        diet
# 259337      10000  2025-07-11 01:22:25   unrelated
# 259338      10000  2025-07-01 13:55:49   unrelated
# 259339      10000  2025-07-06 02:34:55   unrelated
#
# [259340 rows x 3 columns]

# %%
app_session = pd.read_csv('../data/app_usage.csv').drop(columns=['event_type'])
app_session['category'] = 'app_usage'
app_session
# Out:
#        member_id            timestamp   category
# 0              1  2025-07-13 08:43:37  app_usage
# 1              1  2025-07-14 15:28:58  app_usage
# 2              1  2025-07-02 19:43:17  app_usage
# 3              1  2025-07-09 09:40:14  app_usage
# 4              1  2025-07-07 00:39:54  app_usage
# ...          ...                  ...        ...
# 97784      10000  2025-07-01 11:05:24  app_usage
# 97785      10000  2025-07-09 08:43:18  app_usage
# 97786      10000  2025-07-05 11:25:41  app_usage
# 97787      10000  2025-07-04 19:08:59  app_usage
# 97788      10000  2025-07-09 04:35:39  app_usage
#
# [97789 rows x 3 columns]

# %%
claimes = pd.read_csv('../data/claims.csv')
intrests = ['I10', 'E11.9', 'Z71.3']
claimes = claimes[claimes['icd_code'].isin(intrests)]
# rename icd_code  
claimes.rename(columns={'icd_code': 'category', 'diagnosis_date':'timestamp'}, inplace=True)
claimes
# Out:
#        member_id category   timestamp
# 0              1    Z71.3  2025-07-09
# 1              1    Z71.3  2025-07-14
# 4              1      I10  2025-07-12
# 8              1    E11.9  2025-07-09
# 9              2    E11.9  2025-07-08
# ...          ...      ...         ...
# 64563       9999    Z71.3  2025-07-12
# 64564       9999    Z71.3  2025-07-03
# 64566       9999    Z71.3  2025-07-02
# 64569      10000    Z71.3  2025-07-07
# 64575      10000    Z71.3  2025-07-07
#
# [27112 rows x 3 columns]

# %%
combined = pd.concat([web_visits_pattern, app_session, claimes], ignore_index=True)
combined = combined.sort_values(by=['member_id', 'timestamp']).reset_index(drop=True)
combined
# Out:
#         member_id            timestamp    category
# 0               1  2025-07-02 11:30:47   unrelated
# 1               1  2025-07-02 19:43:17   app_usage
# 2               1  2025-07-02 22:38:22    clinical
# 3               1  2025-07-03 04:40:05   app_usage
# 4               1  2025-07-07 00:39:54   app_usage
# ...           ...                  ...         ...
# 384236      10000  2025-07-14 11:06:23    clinical
# 384237      10000  2025-07-14 12:07:57  resilience
# 384238      10000  2025-07-14 13:31:24   app_usage
# 384239      10000  2025-07-14 15:27:50   app_usage
# 384240      10000  2025-07-14 19:23:08       sleep
#
# [384241 rows x 3 columns]

# %%
combined[combined['member_id'] == 45].head(14)
# Out:
#       member_id            timestamp   category
# 1532         45  2025-07-01 04:04:53  app_usage
# 1533         45  2025-07-01 14:19:06  app_usage
# 1534         45  2025-07-02 07:04:46  unrelated
# 1535         45  2025-07-02 23:06:44  app_usage
# 1536         45           2025-07-03      E11.9
# 1537         45  2025-07-03 01:12:44  unrelated
# 1538         45  2025-07-03 05:26:20  app_usage
# 1539         45  2025-07-03 07:07:09  app_usage
# 1540         45  2025-07-03 10:05:25  app_usage
# 1541         45  2025-07-04 03:33:37       diet
# 1542         45  2025-07-04 11:01:34  unrelated
# 1543         45  2025-07-04 11:03:49  unrelated
# 1544         45  2025-07-04 20:24:00  unrelated
# 1545         45  2025-07-04 21:39:09  unrelated

# %%
from collections import defaultdict

def create_sequences(df, member_col='member_id', time_col='timestamp', event_col='category'):
    """
    Convert tabular event data into sequences for pattern mining.
    
    Parameters:
    -----------
    df : pd.DataFrame
        DataFrame with member_id, timestamp, category (sorted)
    
    Returns:
    --------
    list of lists : Each member's sequence of events
    dict : Mapping of member_id to their sequence
    """
    # Group by member and create sequences
    sequences = []
    member_sequences = {}
    
    for member_id, group in df.groupby(member_col):
        sequence = group[event_col].tolist()
        sequences.append(sequence)
        member_sequences[member_id] = sequence
    
    return sequences, member_sequences

# Example usage
sequences, member_dict = create_sequences(combined)

print("First 5 sequences:")
for i, seq in enumerate(sequences[:5]):
    print(f"Member {i+1}: {seq}")
# Out:
# First 5 sequences:
# Member 1: ['unrelated', 'app_usage', 'clinical', 'app_usage', 'app_usage', 'Z71.3', 'E11.9', 'app_usage', 'I10', 'app_usage', 'Z71.3', 'clinical', 'app_usage']
# Member 2: ['diet', 'clinical', 'E11.9', 'app_usage', 'sleep', 'resilience', 'app_usage', 'app_usage', 'I10', 'app_usage', 'clinical', 'clinical', 'E11.9', 'app_usage', 'Z71.3', 'Z71.3', 'unrelated', 'physical_activity', 'E11.9', 'app_usage', 'app_usage', 'app_usage', 'physical_activity', 'app_usage', 'I10', 'app_usage']
# Member 3: ['sleep', 'app_usage', 'unrelated', 'physical_activity', 'app_usage', 'unrelated', 'unrelated', 'clinical', 'resilience', 'sleep', 'unrelated', 'app_usage', 'unrelated', 'clinical', 'unrelated', 'sleep', 'unrelated', 'unrelated', 'physical_activity', 'unrelated', 'app_usage', 'resilience', 'unrelated', 'unrelated', 'app_usage', 'unrelated', 'unrelated', 'unrelated', 'diet', 'unrelated', 'app_usage', 'unrelated', 'unrelated', 'physical_activity', 'physical_activity', 'clinical', 'app_usage', 'unrelated', 'physical_activity', 'sleep', 'unrelated', 'unrelated', 'unrelated', 'diet', 'app_usage', 'unrelated', 'diet', 'app_usage', 'resilience', 'unrelated', 'unrelated', 'clinical', 'clinical', 'unrelated', 'physical_activity', 'E11.9', 'unrelated', 'diet', 'diet', 'unrelated', 'unrelated', 'unrelated']
# Member 4: ['app_usage', 'clinical', 'clinical', 'unrelated', 'sleep', 'app_usage', 'unrelated', 'app_usage', 'unrelated', 'app_usage', 'app_usage', 'app_usage', 'app_usage', 'unrelated', 'resilience', 'app_usage', 'unrelated', 'unrelated', 'resilience', 'unrelated', 'physical_activity', 'I10', 'unrelated', 'app_usage', 'I10', 'I10', 'sleep', 'app_usage']
# Member 5: ['app_usage', 'unrelated', 'app_usage', 'unrelated', 'app_usage', 'unrelated', 'unrelated', 'sleep', 'E11.9', 'Z71.3', 'I10', 'app_usage', 'physical_activity', 'physical_activity', 'E11.9', 'diet', 'app_usage', 'app_usage', 'app_usage', 'app_usage', 'app_usage', 'unrelated', 'clinical', 'app_usage', 'sleep']

# %%
from prefixspan import PrefixSpan

# Prepare sequences (already done above)
sequences, member_dict = create_sequences(combined)

# Initialize PrefixSpan
ps = PrefixSpan(sequences)

# Find frequent patterns
# min_support: minimum number of sequences that must contain the pattern
frequent_patterns = ps.frequent(minsup=10)  # appears in at least 10 members

print("Frequent patterns:")
for support, pattern in frequent_patterns:
    print(f"Support: {support}, Pattern: {pattern}")

# Find top-k most frequent patterns
topk_patterns = ps.topk(k=20)  # top 20 patterns

print("\nTop-K patterns:")
for support, pattern in topk_patterns:
    print(f"Support: {support}, Pattern: {pattern}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 12
#       8 ps = PrefixSpan(sequences)
#      10 # Find frequent patterns
#      11 # min_support: minimum number of sequences that must contain the pattern
# ---> 12 frequent_patterns = ps.frequent(minsup=10)  # appears in at least 10 members
#      14 print("Frequent patterns:")
#      15 for support, pattern in frequent_patterns:
#
# File c:\Users\user\miniconda3\envs\VI\lib\site-packages\prefixspan\frequent.py:70, in PrefixSpan_frequent(self, minsup, closed, generator, key, bound, filter, callback)
#      67 if key is None:
#      68     key = bound = PrefixSpan.defaultkey
# ---> 70 results = self._mine(frequent_rec)
#      72 return None if callback else results
#
# File c:\Users\user\miniconda3\envs\VI\lib\site-packages\prefixspan\prefixspan.py:19, in PrefixSpan._mine(self, func)
#      15 def _mine(self, func):
#      16     # type: (Callable[[Pattern, Matches], None]) -> Any
#      17     self._results.clear()
# ---> 19     func([], [(i, -1) for i in range(len(self._db))])
#      21     return self._results
#
# File c:\Users\user\miniconda3\envs\VI\lib\site-packages\prefixspan\frequent.py:61, in PrefixSpan_frequent.<locals>.frequent_rec(patt, matches)
#      55     if canpass(bound(newpatt, newmatches)) or (
#      56             closed and canclosedprune(self._db, newpatt, newmatches) or
#      57             generator and cangeneratorprune(self._db, newpatt, newmatches, occursstack)
#      58         ):
#      59         continue
# ---> 61     frequent_rec(newpatt, newmatches)
#      63 if generator:
#      64     occursstack.pop()
#
# File c:\Users\user\miniconda3\envs\VI\lib\site-packages\prefixspan\frequent.py:61, in PrefixSpan_frequent.<locals>.frequent_rec(patt, matches)
#      55     if canpass(bound(newpatt, newmatches)) or (
#      56             closed and canclosedprune(self._db, newpatt, newmatches) or
#      57             generator and cangeneratorprune(self._db, newpatt, newmatches, occursstack)
#      58         ):
#      59         continue
# ---> 61     frequent_rec(newpatt, newmatches)
#      63 if generator:
#      64     occursstack.pop()
#
#     [... skipping similar frames: PrefixSpan_frequent.<locals>.frequent_rec at line 61 (12 times)]
#
# File c:\Users\user\miniconda3\envs\VI\lib\site-packages\prefixspan\frequent.py:61, in PrefixSpan_frequent.<locals>.frequent_rec(patt, matches)
#      55     if canpass(bound(newpatt, newmatches)) or (
#      56             closed and canclosedprune(self._db, newpatt, newmatches) or
#      57             generator and cangeneratorprune(self._db, newpatt, newmatches, occursstack)
#      58         ):
#      59         continue
# ---> 61     frequent_rec(newpatt, newmatches)
#      63 if generator:
#      64     occursstack.pop()
#
# File c:\Users\user\miniconda3\envs\VI\lib\site-packages\prefixspan\frequent.py:49, in PrefixSpan_frequent.<locals>.frequent_rec(patt, matches)
#      46     if len(patt) == self.maxlen:
#      47         return
# ---> 49 occurs = nextentries(self._db, matches)
#      50 if generator:
#      51     occursstack.append(occurs)
#
# File c:\Users\user\miniconda3\envs\VI\lib\site-packages\extratools\dicttools.py:66, in nextentries(data, entries)
#      65 def nextentries(data: Sequence[Sequence[T]], entries: Entries) -> Mapping[T, Entries]:
# ---> 66     return invertedindex(
#      67         (data[i][lastpos + 1:] for i, lastpos in entries),
#      68         entries
#      69     )
#
# File c:\Users\user\miniconda3\envs\VI\lib\site-packages\extratools\dicttools.py:55, in invertedindex(seqs, entries)
#      52 for k, seq in enumerate(seqs):
#      53     i, lastpos = entries[k] if entries else (k, -1)
# ---> 55     for p, item in enumerate(seq, start=(lastpos + 1)):
#      56         l = index[item]
#      57         if len(l) and l[-1][0] == i:
#
# KeyboardInterrupt:
